# %% [markdown]
# # Ungraded Lab: Fully Convolutional Neural Networks for Image Segmentation
#
# This notebook illustrates how to build a Fully Convolutional Neural Network for semantic image segmentation.
#
# You will train the model on a [custom dataset](https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view?usp=sharing) prepared by [divamgupta](https://github.com/divamgupta/image-segmentation-keras). This contains video frames from a moving vehicle and is a subsample of the [CamVid](http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamVid/) dataset.
#
# You will be using a pretrained VGG-16 network for the feature extraction path, then followed by an FCN-8 network for upsampling and generating the predictions. The output will be a label map (i.e. segmentation mask) with predictions for 12 classes. Let's begin!

# %% [markdown]
# ## Imports

# %%
import os
import zipfile
import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import numpy as np

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from matplotlib import pyplot as plt
import tensorflow_datasets as tfds
import seaborn as sns

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.7.0

# %% [markdown]
# ## Download the Dataset

# %% [markdown]
# We hosted the dataset in a Google bucket so you will need to download it first and unzip to a local directory.

# %%
# download the dataset (zipped file)
# !gdown --id 0B0d9ZiqAgFkiOHR1NTJhWVJMNEU -O /tmp/fcnn-dataset.zip 

# extract the downloaded dataset to a local directory: /tmp/fcnn
local_zip = '/tmp/fcnn-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/fcnn')
zip_ref.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B0d9ZiqAgFkiOHR1NTJhWVJMNEU
# To: /tmp/fcnn-dataset.zip
# 100% 126M/126M [00:01<00:00, 109MB/s]

# %% [markdown]
# The dataset you just downloaded contains folders for images and annotations. The *images* contain the video frames while the *annotations* contain the pixel-wise label maps. Each label map has the shape `(height, width , 1)` with each point in this space denoting the corresponding pixel's class. Classes are in the range `[0, 11]` (i.e. 12 classes) and the pixel labels correspond to these classes:
#
# | Value  | Class Name    |
# | -------| -------------|
# | 0      | sky |
# | 1      | building      |
# | 2      | column/pole      |
# | 3      | road |
# | 4      | side walk     |
# | 5      | vegetation      |
# | 6      | traffic light |
# | 7      | fence      |
# | 8      | vehicle     |
# | 9      | pedestrian |
# | 10      | byciclist      |
# | 11      | void      |
#
# For example, if a pixel is part of a road, then that point will be labeled `3` in the label map. Run the cell below to create a list containing the class names:
# - Note: bicyclist is mispelled as 'byciclist' in the dataset.  We won't handle data cleaning in this example, but you can inspect and clean the data if you want to use this as a starting point for a personal project.

# %%
# pixel labels in the video frames
class_names = ['sky', 'building','column/pole', 'road', 'side walk', 'vegetation', 'traffic light', 'fence', 'vehicle', 'pedestrian', 'byciclist', 'void']

# %% [markdown]
# ## Load and Prepare the Dataset

# %% [markdown]
# Next, you will load and prepare the train and validation sets for training. There are some preprocessing steps needed before the data is fed to the model. These include:
#
# * resizing the height and width of the input images and label maps (224 x 224px by default)
# * normalizing the input images' pixel values to fall in the range `[-1, 1]`
# * reshaping the label maps from `(height, width, 1)` to `(height, width, 12)` with each slice along the third axis having `1` if it belongs to the class corresponding to that slice's index else `0`. For example, if a pixel is part of a road, then using the table above, that point at slice #3 will be labeled `1` and it will be `0` in all other slices. To illustrate using simple arrays:
# ```
# # if we have a label map with 3 classes...
# n_classes = 3
# # and this is the original annotation...
# orig_anno = [0 1 2]
# # then the reshaped annotation will have 3 slices and its contents will look like this:
# reshaped_anno = [1 0 0][0 1 0][0 0 1]
# ```
#
# The following function will do the preprocessing steps mentioned above.

# %%
def map_filename_to_image_and_mask(t_filename, a_filename, height=224, width=224):
  '''
  Preprocesses the dataset by:
    * resizing the input image and label maps
    * normalizing the input image pixels
    * reshaping the label maps from (height, width, 1) to (height, width, 12)

  Args:
    t_filename (string) -- path to the raw input image
    a_filename (string) -- path to the raw annotation (label map) file
    height (int) -- height in pixels to resize to
    width (int) -- width in pixels to resize to

  Returns:
    image (tensor) -- preprocessed image
    annotation (tensor) -- preprocessed annotation
  '''

  # Convert image and mask files to tensors 
  img_raw = tf.io.read_file(t_filename)
  anno_raw = tf.io.read_file(a_filename)
  image = tf.image.decode_jpeg(img_raw)
  annotation = tf.image.decode_jpeg(anno_raw)
 
  # Resize image and segmentation mask
  image = tf.image.resize(image, (height, width,))
  annotation = tf.image.resize(annotation, (height, width,))
  image = tf.reshape(image, (height, width, 3,))
  annotation = tf.cast(annotation, dtype=tf.int32)
  annotation = tf.reshape(annotation, (height, width, 1,))
  stack_list = []

  # Reshape segmentation masks
  for c in range(len(class_names)):
    mask = tf.equal(annotation[:,:,0], tf.constant(c))
    stack_list.append(tf.cast(mask, dtype=tf.int32))
  
  annotation = tf.stack(stack_list, axis=2)

  # Normalize pixels in the input image
  image = image/127.5
  image -= 1

  return image, annotation

# %% [markdown]
# The dataset also already has separate folders for train and test sets. As described earlier, these sets will have two folders: one corresponding to the images, and the other containing the annotations.

# %%
# show folders inside the dataset you downloaded
# !ls /tmp/fcnn/dataset1
# Out:
# annotations_prepped_test   images_prepped_test
# annotations_prepped_train  images_prepped_train

# %% [markdown]
# You will use the following functions to create the tensorflow datasets from the images in these folders. Notice that before creating the batches in the `get_training_dataset()` and `get_validation_set()`, the images are first preprocessed using the `map_filename_to_image_and_mask()` function you defined earlier.

# %%
# Utilities for preparing the datasets

BATCH_SIZE = 64

def get_dataset_slice_paths(image_dir, label_map_dir):
  '''
  generates the lists of image and label map paths
  
  Args:
    image_dir (string) -- path to the input images directory
    label_map_dir (string) -- path to the label map directory

  Returns:
    image_paths (list of strings) -- paths to each image file
    label_map_paths (list of strings) -- paths to each label map
  '''
  image_file_list = os.listdir(image_dir)
  label_map_file_list = os.listdir(label_map_dir)
  image_paths = [os.path.join(image_dir, fname) for fname in image_file_list]
  label_map_paths = [os.path.join(label_map_dir, fname) for fname in label_map_file_list]

  return image_paths, label_map_paths


def get_training_dataset(image_paths, label_map_paths):
  '''
  Prepares shuffled batches of the training set.
  
  Args:
    image_paths (list of strings) -- paths to each image file in the train set
    label_map_paths (list of strings) -- paths to each label map in the train set

  Returns:
    tf Dataset containing the preprocessed train set
  '''
  training_dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_map_paths))
  training_dataset = training_dataset.map(map_filename_to_image_and_mask)
  training_dataset = training_dataset.shuffle(100, reshuffle_each_iteration=True)
  training_dataset = training_dataset.batch(BATCH_SIZE)
  training_dataset = training_dataset.repeat()
  training_dataset = training_dataset.prefetch(-1)

  return training_dataset


def get_validation_dataset(image_paths, label_map_paths):
  '''
  Prepares batches of the validation set.
  
  Args:
    image_paths (list of strings) -- paths to each image file in the val set
    label_map_paths (list of strings) -- paths to each label map in the val set

  Returns:
    tf Dataset containing the preprocessed validation set
  '''
  validation_dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_map_paths))
  validation_dataset = validation_dataset.map(map_filename_to_image_and_mask)
  validation_dataset = validation_dataset.batch(BATCH_SIZE)
  validation_dataset = validation_dataset.repeat()  

  return validation_dataset

# %% [markdown]
# You can now generate the training and validation sets by running the cell below.

# %%
# get the paths to the images
INPUT_PATH = '/tmp/fcnn/dataset1'
train_image_dir, train_label_map_dir = os.path.join(INPUT_PATH, 'images_prepped_train'), os.path.join(INPUT_PATH, 'annotations_prepped_train')
valid_image_dir, valid_label_map_dir = os.path.join(INPUT_PATH, 'images_prepped_test'), os.path.join(INPUT_PATH, 'annotations_prepped_test')

train_image_paths, train_label_map_paths = get_dataset_slice_paths(train_image_dir, train_label_map_dir)
valid_image_paths, valid_label_map_paths = get_dataset_slice_paths(valid_image_dir, valid_label_map_dir)

# generate the train and val sets
training_dataset = get_training_dataset(train_image_paths, train_label_map_paths)
validation_dataset = get_validation_dataset(valid_image_paths, valid_label_map_paths)

# %% [markdown]
# ## Let's Take a Look at the Dataset

# %% [markdown]
# You will also need utilities to help visualize the dataset and the model predictions later. First, you need to assign a color mapping to the classes in the label maps. Since our dataset has 12 classes, you need to have a list of 12 colors. We can use the [color_palette()](https://seaborn.pydata.org/generated/seaborn.color_palette.html) from Seaborn to generate this.

# %%
# generate a list that contains one color for each class
colors = sns.color_palette(None, len(class_names))

# print class name - normalized RGB tuple pairs
# the tuple values will be multiplied by 255 in the helper functions later
# to convert to the (0,0,0) to (255,255,255) RGB values you might be familiar with
for class_name, color in zip(class_names, colors):
  print(f'{class_name} -- {color}')
# Out:
# sky -- (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
# building -- (1.0, 0.4980392156862745, 0.054901960784313725)
# column/pole -- (0.17254901960784313, 0.6274509803921569, 0.17254901960784313)
# road -- (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)
# side walk -- (0.5803921568627451, 0.403921568627451, 0.7411764705882353)
# vegetation -- (0.5490196078431373, 0.33725490196078434, 0.29411764705882354)
# traffic light -- (0.8901960784313725, 0.4666666666666667, 0.7607843137254902)
# fence -- (0.4980392156862745, 0.4980392156862745, 0.4980392156862745)
# vehicle -- (0.7372549019607844, 0.7411764705882353, 0.13333333333333333)
# pedestrian -- (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)
# byciclist -- (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
# void -- (1.0, 0.4980392156862745, 0.054901960784313725)

# %%
# Visualization Utilities

def fuse_with_pil(images):
  '''
  Creates a blank image and pastes input images

  Args:
    images (list of numpy arrays) - numpy array representations of the images to paste
  
  Returns:
    PIL Image object containing the images
  '''

  widths = (image.shape[1] for image in images)
  heights = (image.shape[0] for image in images)
  total_width = sum(widths)
  max_height = max(heights)

  new_im = PIL.Image.new('RGB', (total_width, max_height))

  x_offset = 0
  for im in images:
    pil_image = PIL.Image.fromarray(np.uint8(im))
    new_im.paste(pil_image, (x_offset,0))
    x_offset += im.shape[1]
  
  return new_im


def give_color_to_annotation(annotation):
  '''
  Converts a 2-D annotation to a numpy array with shape (height, width, 3) where
  the third axis represents the color channel. The label values are multiplied by
  255 and placed in this axis to give color to the annotation

  Args:
    annotation (numpy array) - label map array
  
  Returns:
    the annotation array with an additional color channel/axis
  '''
  seg_img = np.zeros( (annotation.shape[0],annotation.shape[1], 3) ).astype('float')
  
  for c in range(12):
    segc = (annotation == c)
    seg_img[:,:,0] += segc*( colors[c][0] * 255.0)
    seg_img[:,:,1] += segc*( colors[c][1] * 255.0)
    seg_img[:,:,2] += segc*( colors[c][2] * 255.0)
  
  return seg_img


def show_predictions(image, labelmaps, titles, iou_list, dice_score_list):
  '''
  Displays the images with the ground truth and predicted label maps

  Args:
    image (numpy array) -- the input image
    labelmaps (list of arrays) -- contains the predicted and ground truth label maps
    titles (list of strings) -- display headings for the images to be displayed
    iou_list (list of floats) -- the IOU values for each class
    dice_score_list (list of floats) -- the Dice Score for each vlass
  '''

  true_img = give_color_to_annotation(labelmaps[1])
  pred_img = give_color_to_annotation(labelmaps[0])

  image = image + 1
  image = image * 127.5
  images = np.uint8([image, pred_img, true_img])

  metrics_by_id = [(idx, iou, dice_score) for idx, (iou, dice_score) in enumerate(zip(iou_list, dice_score_list)) if iou > 0.0]
  metrics_by_id.sort(key=lambda tup: tup[1], reverse=True)  # sorts in place
  
  display_string_list = ["{}: IOU: {} Dice Score: {}".format(class_names[idx], iou, dice_score) for idx, iou, dice_score in metrics_by_id]
  display_string = "\n\n".join(display_string_list) 

  plt.figure(figsize=(15, 4))

  for idx, im in enumerate(images):
    plt.subplot(1, 3, idx+1)
    if idx == 1:
      plt.xlabel(display_string)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[idx], fontsize=12)
    plt.imshow(im)


def show_annotation_and_image(image, annotation):
  '''
  Displays the image and its annotation side by side

  Args:
    image (numpy array) -- the input image
    annotation (numpy array) -- the label map
  '''
  new_ann = np.argmax(annotation, axis=2)
  seg_img = give_color_to_annotation(new_ann)
  
  image = image + 1
  image = image * 127.5
  image = np.uint8(image)
  images = [image, seg_img]
  
  fused_img = fuse_with_pil(images)
  plt.imshow(fused_img)


def list_show_annotation(dataset):
  '''
  Displays images and its annotations side by side

  Args:
    dataset (tf Dataset) - batch of images and annotations
  '''

  ds = dataset.unbatch()
  ds = ds.shuffle(buffer_size=100)

  plt.figure(figsize=(25, 15))
  plt.title("Images And Annotations")
  plt.subplots_adjust(bottom=0.1, top=0.9, hspace=0.05)

  # we set the number of image-annotation pairs to 9
  # feel free to make this a function parameter if you want
  for idx, (image, annotation) in enumerate(ds.take(9)):
    plt.subplot(3, 3, idx + 1)
    plt.yticks([])
    plt.xticks([])
    show_annotation_and_image(image.numpy(), annotation.numpy())

# %% [markdown]
# Please run the cells below to see sample images from the train and validation sets. You will see the image and the label maps side side by side.

# %%
list_show_annotation(training_dataset)

# %%
list_show_annotation(validation_dataset)

# %% [markdown]
# ## Define the Model
#
# You will now build the model and prepare it for training. AS mentioned earlier, this will use a VGG-16 network for the encoder and FCN-8 for the decoder. This is the diagram as shown in class:
#
# <img src='https://drive.google.com/uc?export=view&id=1lrqB4YegV8jXWNfyYAaeuFlwXIc54aRP' alt='fcn-8'>
#
# For this exercise, you will notice a slight difference from the lecture because the dataset images are 224x224 instead of 32x32. You'll see how this is handled in the next cells as you build the encoder.

# %% [markdown]
# ### Define Pooling Block of VGG

# %% [markdown]
# As you saw in Course 1 of this specialization, VGG networks have repeating blocks so to make the code neat, it's best to create a function to encapsulate this process. Each block has convolutional layers followed by a max pooling layer which downsamples the image.

# %% [markdown]
# ### Download VGG weights
#
# First, please run the cell below to get pre-trained weights for VGG-16. You will load this in the next section when you build the encoder network.

# %% [markdown]
# ### Define VGG-16
#
# You can build the encoder as shown below.
#
# * You will create 5 blocks with increasing number of filters at each stage.
# * The number of convolutions, filters, kernel size, activation, pool size and pool stride will remain constant.
# * You will load the pretrained weights after creating the VGG 16 network.
# * Additional convolution layers will be appended to extract more features.
# * The output will contain the output of the last layer and the previous four convolution blocks.

# %%
def VGG_16():

  vgg = tf.keras.applications.vgg16.VGG16(include_top=False, weights='imagenet', input_tensor=None, input_shape=(224, 224, 3))

  i = 1
  p_s = dict()
  for layer in vgg.layers:
    if layer.name.endswith('pool'):
      p_s[f'p{i}'] = layer.output
      i += 1

  n = 4096
  c6 = tf.keras.layers.Conv2D(n, 7, activation='relu', padding='same', name='conv6')(p_s['p5'])
  c7 = tf.keras.layers.Conv2D(n, 1, activation='relu', padding='same', name='conv7')(c6)
  model = tf.keras.Model(inputs=vgg.layers[0].input, outputs=c7)
  
  return model

# %% [markdown]
# ### Define FCN 8 Decoder
#
# Next, you will build the decoder using deconvolution layers. Please refer to the diagram for FCN-8 at the start of this section to visualize what the code below is doing. It will involve two summations before upsampling to the original image size and generating the predicted mask.

# %%
def fcn8_decoder(vgg, n_classes):
  
  i = 1
  p_s = dict()
  for layer in vgg.layers:
    if layer.name.endswith('pool'):
      p_s[f'p{i}'] = layer.output
      i += 1

  c7 = vgg.layers[-1].output
  f1, f2, f3, f4, f5 = p_s['p1'], p_s['p2'], p_s['p3'], p_s['p4'], c7
  o = tf.keras.layers.Conv2DTranspose(n_classes, kernel_size=4, strides=2, use_bias=False)(f5)
  o = tf.keras.layers.Cropping2D(cropping=1)(o)

  o2 = f4
  o2 = tf.keras.layers.Conv2D(n_classes, kernel_size=1, padding='same', activation='relu')(o2)

  o = tf.keras.layers.Add()([o, o2])

  o = tf.keras.layers.Conv2DTranspose(n_classes, kernel_size=4, strides=2, use_bias=False)(o)
  o = tf.keras.layers.Cropping2D(cropping=1)(o)

  o2 = f3
  o2 = tf.keras.layers.Conv2D(n_classes, kernel_size=1, padding='same', activation='relu')(o2)

  o = tf.keras.layers.Add()([o, o2])

  o = tf.keras.layers.Conv2DTranspose(n_classes, kernel_size=8, strides=8, use_bias=False)(o)
  o = tf.keras.layers.Activation('softmax')(o)

  return o

# %% [markdown]
# ### Define Final Model
#
# You can now build the final model by connecting the encoder and decoder blocks.

# %%
def segmentation_model():

  vgg = VGG_16()
  outputs = fcn8_decoder(vgg, 12)
  model = tf.keras.Model(inputs=vgg.input, outputs=outputs)

  return model

# %%
# instantiate the model and see how it looks
model = segmentation_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 112, 112, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 112, 112, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 112, 112, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 56, 56, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 56, 56, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 28, 28, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 14, 14, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 7, 7, 512)    0           ['block5_conv3[0][0]']
#
#  conv6 (Conv2D)                 (None, 7, 7, 4096)   102764544   ['block5_pool[0][0]']
#
#  conv7 (Conv2D)                 (None, 7, 7, 4096)   16781312    ['conv6[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 12)  786432      ['conv7[0][0]']
#  ose)
#
#  cropping2d (Cropping2D)        (None, 14, 14, 12)   0           ['conv2d_transpose[0][0]']
#
#  conv2d (Conv2D)                (None, 14, 14, 12)   6156        ['block4_pool[0][0]']
#
#  add (Add)                      (None, 14, 14, 12)   0           ['cropping2d[0][0]',
#                                                                   'conv2d[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 30, 30, 12)  2304        ['add[0][0]']
#  spose)
#
#  cropping2d_1 (Cropping2D)      (None, 28, 28, 12)   0           ['conv2d_transpose_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 12)   3084        ['block3_pool[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 12)   0           ['cropping2d_1[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 224, 224, 12  9216       ['add_1[0][0]']
#  spose)                         )
#
#  activation (Activation)        (None, 224, 224, 12  0           ['conv2d_transpose_2[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 135,067,736
# Trainable params: 135,067,736
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %% [markdown]
# Next, the model will be configured for training. You will need to specify the loss, optimizer and metrics. You will use `categorical_crossentropy` as the loss function since the label map is transformed to one hot encoded vectors for each pixel in the image (i.e. `1` in one slice and `0` for other slices as described earlier).

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-2, momentum=0.9, nesterov=True)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              optimizer=optimizer,
              metrics=tf.keras.metrics.CategoricalAccuracy())

# %% [markdown]
# ## Train the Model
#
# The model can now be trained. This will take around 30 minutes to run and you will reach around 85% accuracy for both train and val sets.

# %%
# number of training images
train_count = 367

# number of validation images
validation_count = 101

EPOCHS = 170

steps_per_epoch = train_count//BATCH_SIZE
validation_steps = validation_count//BATCH_SIZE

history = model.fit(training_dataset,
                    steps_per_epoch=steps_per_epoch, validation_data=validation_dataset, validation_steps=validation_steps, epochs=EPOCHS)
# Out:
# Epoch 1/170
# 5/5 [==============================] - 68s 4s/step - loss: 2.6249 - categorical_accuracy: 0.0911 - val_loss: 2.4854 - val_categorical_accuracy: 0.0881
# Epoch 2/170
# 5/5 [==============================] - 48s 4s/step - loss: 2.4837 - categorical_accuracy: 0.0936 - val_loss: 2.4815 - val_categorical_accuracy: 0.0948
# Epoch 3/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.4781 - categorical_accuracy: 0.1028 - val_loss: 2.4791 - val_categorical_accuracy: 0.1021
# Epoch 4/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.4731 - categorical_accuracy: 0.1098 - val_loss: 2.4731 - val_categorical_accuracy: 0.1101
# Epoch 5/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.4641 - categorical_accuracy: 0.1190 - val_loss: 2.4614 - val_categorical_accuracy: 0.1228
# Epoch 6/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.4450 - categorical_accuracy: 0.1355 - val_loss: 2.4399 - val_categorical_accuracy: 0.1410
# Epoch 7/170
# 5/5 [==============================] - 19s 4s/step - loss: 2.4110 - categorical_accuracy: 0.1573 - val_loss: 2.3977 - val_categorical_accuracy: 0.1661
# Epoch 8/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.3435 - categorical_accuracy: 0.1887 - val_loss: 2.3161 - val_categorical_accuracy: 0.2032
# Epoch 9/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.2321 - categorical_accuracy: 0.2327 - val_loss: 2.3525 - val_categorical_accuracy: 0.2377
# Epoch 10/170
# 5/5 [==============================] - 18s 4s/step - loss: 2.2709 - categorical_accuracy: 0.2498 - val_loss: 2.1392 - val_categorical_accuracy: 0.2732
# Epoch 11/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.9961 - categorical_accuracy: 0.3044 - val_loss: 1.9986 - val_categorical_accuracy: 0.2878
# Epoch 12/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.9138 - categorical_accuracy: 0.3181 - val_loss: 2.0690 - val_categorical_accuracy: 0.2933
# Epoch 13/170
# 5/5 [==============================] - 20s 4s/step - loss: 1.8523 - categorical_accuracy: 0.3269 - val_loss: 1.9349 - val_categorical_accuracy: 0.2953
# Epoch 14/170
# 5/5 [==============================] - 19s 4s/step - loss: 1.8078 - categorical_accuracy: 0.3228 - val_loss: 1.9183 - val_categorical_accuracy: 0.2981
# Epoch 15/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.7646 - categorical_accuracy: 0.3259 - val_loss: 1.9187 - val_categorical_accuracy: 0.2998
# Epoch 16/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.6814 - categorical_accuracy: 0.3450 - val_loss: 1.8705 - val_categorical_accuracy: 0.3167
# Epoch 17/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.7427 - categorical_accuracy: 0.3595 - val_loss: 1.8978 - val_categorical_accuracy: 0.3402
# Epoch 18/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.6380 - categorical_accuracy: 0.3882 - val_loss: 1.7895 - val_categorical_accuracy: 0.3743
# Epoch 19/170
# 5/5 [==============================] - 19s 4s/step - loss: 1.5705 - categorical_accuracy: 0.4335 - val_loss: 1.7346 - val_categorical_accuracy: 0.4352
# Epoch 20/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.5174 - categorical_accuracy: 0.4828 - val_loss: 1.6328 - val_categorical_accuracy: 0.4799
# Epoch 21/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.4649 - categorical_accuracy: 0.5302 - val_loss: 1.6814 - val_categorical_accuracy: 0.4952
# Epoch 22/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.3828 - categorical_accuracy: 0.5813 - val_loss: 1.4721 - val_categorical_accuracy: 0.5648
# Epoch 23/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.2171 - categorical_accuracy: 0.6468 - val_loss: 1.4360 - val_categorical_accuracy: 0.5824
# Epoch 24/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.1659 - categorical_accuracy: 0.6610 - val_loss: 1.3229 - val_categorical_accuracy: 0.5979
# Epoch 25/170
# 5/5 [==============================] - 19s 4s/step - loss: 1.1958 - categorical_accuracy: 0.6499 - val_loss: 1.3355 - val_categorical_accuracy: 0.5873
# Epoch 26/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.0931 - categorical_accuracy: 0.6704 - val_loss: 1.2364 - val_categorical_accuracy: 0.6069
# Epoch 27/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.0651 - categorical_accuracy: 0.6777 - val_loss: 1.2089 - val_categorical_accuracy: 0.6091
# Epoch 28/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.0226 - categorical_accuracy: 0.6823 - val_loss: 1.1872 - val_categorical_accuracy: 0.6096
# Epoch 29/170
# 5/5 [==============================] - 18s 4s/step - loss: 1.0043 - categorical_accuracy: 0.6880 - val_loss: 1.1588 - val_categorical_accuracy: 0.6124
# Epoch 30/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9973 - categorical_accuracy: 0.6823 - val_loss: 1.1593 - val_categorical_accuracy: 0.6079
# Epoch 31/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.9769 - categorical_accuracy: 0.6857 - val_loss: 1.1209 - val_categorical_accuracy: 0.6121
# Epoch 32/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9534 - categorical_accuracy: 0.6895 - val_loss: 1.1026 - val_categorical_accuracy: 0.6120
# Epoch 33/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9442 - categorical_accuracy: 0.6890 - val_loss: 1.1056 - val_categorical_accuracy: 0.6090
# Epoch 34/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9749 - categorical_accuracy: 0.6851 - val_loss: 1.0743 - val_categorical_accuracy: 0.6177
# Epoch 35/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9405 - categorical_accuracy: 0.6898 - val_loss: 1.0791 - val_categorical_accuracy: 0.6107
# Epoch 36/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9213 - categorical_accuracy: 0.6906 - val_loss: 1.0514 - val_categorical_accuracy: 0.6144
# Epoch 37/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.9051 - categorical_accuracy: 0.6950 - val_loss: 1.0446 - val_categorical_accuracy: 0.6145
# Epoch 38/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.9210 - categorical_accuracy: 0.6848 - val_loss: 1.0338 - val_categorical_accuracy: 0.6173
# Epoch 39/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8765 - categorical_accuracy: 0.7023 - val_loss: 1.0203 - val_categorical_accuracy: 0.6179
# Epoch 40/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8853 - categorical_accuracy: 0.6964 - val_loss: 1.0106 - val_categorical_accuracy: 0.6199
# Epoch 41/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8820 - categorical_accuracy: 0.6968 - val_loss: 1.0471 - val_categorical_accuracy: 0.6083
# Epoch 42/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8827 - categorical_accuracy: 0.6991 - val_loss: 1.0151 - val_categorical_accuracy: 0.6245
# Epoch 43/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.8835 - categorical_accuracy: 0.6981 - val_loss: 1.0250 - val_categorical_accuracy: 0.6138
# Epoch 44/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8660 - categorical_accuracy: 0.7006 - val_loss: 1.0029 - val_categorical_accuracy: 0.6159
# Epoch 45/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8539 - categorical_accuracy: 0.7053 - val_loss: 1.0080 - val_categorical_accuracy: 0.6125
# Epoch 46/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8277 - categorical_accuracy: 0.7139 - val_loss: 0.9898 - val_categorical_accuracy: 0.6165
# Epoch 47/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8375 - categorical_accuracy: 0.7110 - val_loss: 1.0895 - val_categorical_accuracy: 0.5881
# Epoch 48/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8365 - categorical_accuracy: 0.7158 - val_loss: 0.9942 - val_categorical_accuracy: 0.6129
# Epoch 49/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.8232 - categorical_accuracy: 0.7159 - val_loss: 0.9926 - val_categorical_accuracy: 0.6130
# Epoch 50/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8416 - categorical_accuracy: 0.7162 - val_loss: 0.9928 - val_categorical_accuracy: 0.6214
# Epoch 51/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8132 - categorical_accuracy: 0.7196 - val_loss: 0.9737 - val_categorical_accuracy: 0.6149
# Epoch 52/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8059 - categorical_accuracy: 0.7208 - val_loss: 0.9688 - val_categorical_accuracy: 0.6175
# Epoch 53/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8014 - categorical_accuracy: 0.7265 - val_loss: 0.9957 - val_categorical_accuracy: 0.6086
# Epoch 54/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7978 - categorical_accuracy: 0.7277 - val_loss: 0.9871 - val_categorical_accuracy: 0.6146
# Epoch 55/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.7893 - categorical_accuracy: 0.7279 - val_loss: 0.9490 - val_categorical_accuracy: 0.6199
# Epoch 56/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7726 - categorical_accuracy: 0.7339 - val_loss: 0.9750 - val_categorical_accuracy: 0.6105
# Epoch 57/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.8108 - categorical_accuracy: 0.7239 - val_loss: 0.9546 - val_categorical_accuracy: 0.6215
# Epoch 58/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7905 - categorical_accuracy: 0.7301 - val_loss: 0.9358 - val_categorical_accuracy: 0.6254
# Epoch 59/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7593 - categorical_accuracy: 0.7418 - val_loss: 0.9328 - val_categorical_accuracy: 0.6364
# Epoch 60/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7516 - categorical_accuracy: 0.7454 - val_loss: 0.9532 - val_categorical_accuracy: 0.6497
# Epoch 61/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.7942 - categorical_accuracy: 0.7411 - val_loss: 0.9214 - val_categorical_accuracy: 0.6497
# Epoch 62/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7614 - categorical_accuracy: 0.7462 - val_loss: 0.8833 - val_categorical_accuracy: 0.6840
# Epoch 63/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7338 - categorical_accuracy: 0.7655 - val_loss: 0.8772 - val_categorical_accuracy: 0.6991
# Epoch 64/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7217 - categorical_accuracy: 0.7739 - val_loss: 0.8538 - val_categorical_accuracy: 0.7185
# Epoch 65/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7180 - categorical_accuracy: 0.7803 - val_loss: 0.9130 - val_categorical_accuracy: 0.7122
# Epoch 66/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7952 - categorical_accuracy: 0.7509 - val_loss: 0.8647 - val_categorical_accuracy: 0.7346
# Epoch 67/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.7099 - categorical_accuracy: 0.7861 - val_loss: 0.8297 - val_categorical_accuracy: 0.7524
# Epoch 68/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7016 - categorical_accuracy: 0.7930 - val_loss: 0.8106 - val_categorical_accuracy: 0.7587
# Epoch 69/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.7005 - categorical_accuracy: 0.7949 - val_loss: 0.8054 - val_categorical_accuracy: 0.7538
# Epoch 70/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6959 - categorical_accuracy: 0.7938 - val_loss: 0.7751 - val_categorical_accuracy: 0.7735
# Epoch 71/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6912 - categorical_accuracy: 0.7963 - val_loss: 0.7735 - val_categorical_accuracy: 0.7649
# Epoch 72/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6719 - categorical_accuracy: 0.8029 - val_loss: 0.7721 - val_categorical_accuracy: 0.7680
# Epoch 73/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.6642 - categorical_accuracy: 0.8051 - val_loss: 0.7351 - val_categorical_accuracy: 0.7881
# Epoch 74/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6840 - categorical_accuracy: 0.7983 - val_loss: 0.7690 - val_categorical_accuracy: 0.7664
# Epoch 75/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6685 - categorical_accuracy: 0.8023 - val_loss: 0.7359 - val_categorical_accuracy: 0.7805
# Epoch 76/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6449 - categorical_accuracy: 0.8109 - val_loss: 0.7270 - val_categorical_accuracy: 0.7792
# Epoch 77/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6433 - categorical_accuracy: 0.8108 - val_loss: 0.7353 - val_categorical_accuracy: 0.7725
# Epoch 78/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6559 - categorical_accuracy: 0.8051 - val_loss: 0.7116 - val_categorical_accuracy: 0.7894
# Epoch 79/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.6437 - categorical_accuracy: 0.8113 - val_loss: 0.7118 - val_categorical_accuracy: 0.7853
# Epoch 80/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6269 - categorical_accuracy: 0.8169 - val_loss: 0.6915 - val_categorical_accuracy: 0.8020
# Epoch 81/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6395 - categorical_accuracy: 0.8123 - val_loss: 0.7174 - val_categorical_accuracy: 0.7857
# Epoch 82/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6255 - categorical_accuracy: 0.8175 - val_loss: 0.6768 - val_categorical_accuracy: 0.7990
# Epoch 83/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6324 - categorical_accuracy: 0.8142 - val_loss: 0.8107 - val_categorical_accuracy: 0.7460
# Epoch 84/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6636 - categorical_accuracy: 0.8046 - val_loss: 0.6939 - val_categorical_accuracy: 0.7912
# Epoch 85/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.6221 - categorical_accuracy: 0.8179 - val_loss: 0.7031 - val_categorical_accuracy: 0.7825
# Epoch 86/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6079 - categorical_accuracy: 0.8224 - val_loss: 0.6621 - val_categorical_accuracy: 0.8050
# Epoch 87/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6010 - categorical_accuracy: 0.8258 - val_loss: 0.6528 - val_categorical_accuracy: 0.8105
# Epoch 88/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5975 - categorical_accuracy: 0.8251 - val_loss: 0.6601 - val_categorical_accuracy: 0.8054
# Epoch 89/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6071 - categorical_accuracy: 0.8230 - val_loss: 0.6493 - val_categorical_accuracy: 0.8098
# Epoch 90/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5842 - categorical_accuracy: 0.8305 - val_loss: 0.6377 - val_categorical_accuracy: 0.8202
# Epoch 91/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.6426 - categorical_accuracy: 0.8127 - val_loss: 0.8121 - val_categorical_accuracy: 0.7535
# Epoch 92/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6203 - categorical_accuracy: 0.8207 - val_loss: 0.6552 - val_categorical_accuracy: 0.8099
# Epoch 93/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5974 - categorical_accuracy: 0.8263 - val_loss: 0.6502 - val_categorical_accuracy: 0.8143
# Epoch 94/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5731 - categorical_accuracy: 0.8344 - val_loss: 0.6291 - val_categorical_accuracy: 0.8195
# Epoch 95/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5848 - categorical_accuracy: 0.8306 - val_loss: 0.6187 - val_categorical_accuracy: 0.8239
# Epoch 96/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5738 - categorical_accuracy: 0.8342 - val_loss: 0.6201 - val_categorical_accuracy: 0.8237
# Epoch 97/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5696 - categorical_accuracy: 0.8350 - val_loss: 0.6125 - val_categorical_accuracy: 0.8254
# Epoch 98/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.6040 - categorical_accuracy: 0.8234 - val_loss: 0.6829 - val_categorical_accuracy: 0.8026
# Epoch 99/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5736 - categorical_accuracy: 0.8357 - val_loss: 0.6256 - val_categorical_accuracy: 0.8190
# Epoch 100/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5601 - categorical_accuracy: 0.8382 - val_loss: 0.6080 - val_categorical_accuracy: 0.8262
# Epoch 101/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5650 - categorical_accuracy: 0.8361 - val_loss: 0.5862 - val_categorical_accuracy: 0.8339
# Epoch 102/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5525 - categorical_accuracy: 0.8403 - val_loss: 0.6070 - val_categorical_accuracy: 0.8292
# Epoch 103/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5608 - categorical_accuracy: 0.8376 - val_loss: 0.5832 - val_categorical_accuracy: 0.8344
# Epoch 104/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5449 - categorical_accuracy: 0.8421 - val_loss: 0.6079 - val_categorical_accuracy: 0.8255
# Epoch 105/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5808 - categorical_accuracy: 0.8317 - val_loss: 0.6084 - val_categorical_accuracy: 0.8349
# Epoch 106/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5667 - categorical_accuracy: 0.8355 - val_loss: 0.6138 - val_categorical_accuracy: 0.8232
# Epoch 107/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5438 - categorical_accuracy: 0.8428 - val_loss: 0.5854 - val_categorical_accuracy: 0.8316
# Epoch 108/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5428 - categorical_accuracy: 0.8423 - val_loss: 0.5886 - val_categorical_accuracy: 0.8313
# Epoch 109/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5424 - categorical_accuracy: 0.8424 - val_loss: 0.5986 - val_categorical_accuracy: 0.8297
# Epoch 110/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5360 - categorical_accuracy: 0.8445 - val_loss: 0.5746 - val_categorical_accuracy: 0.8364
# Epoch 111/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5441 - categorical_accuracy: 0.8409 - val_loss: 0.5892 - val_categorical_accuracy: 0.8319
# Epoch 112/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5332 - categorical_accuracy: 0.8443 - val_loss: 0.5679 - val_categorical_accuracy: 0.8375
# Epoch 113/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5516 - categorical_accuracy: 0.8385 - val_loss: 0.6477 - val_categorical_accuracy: 0.8094
# Epoch 114/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5542 - categorical_accuracy: 0.8389 - val_loss: 0.5758 - val_categorical_accuracy: 0.8373
# Epoch 115/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5354 - categorical_accuracy: 0.8439 - val_loss: 0.5814 - val_categorical_accuracy: 0.8345
# Epoch 116/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5203 - categorical_accuracy: 0.8489 - val_loss: 0.5616 - val_categorical_accuracy: 0.8365
# Epoch 117/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5237 - categorical_accuracy: 0.8468 - val_loss: 0.5582 - val_categorical_accuracy: 0.8389
# Epoch 118/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5331 - categorical_accuracy: 0.8446 - val_loss: 0.5461 - val_categorical_accuracy: 0.8446
# Epoch 119/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5326 - categorical_accuracy: 0.8449 - val_loss: 0.5772 - val_categorical_accuracy: 0.8307
# Epoch 120/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5160 - categorical_accuracy: 0.8494 - val_loss: 0.5525 - val_categorical_accuracy: 0.8400
# Epoch 121/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5134 - categorical_accuracy: 0.8496 - val_loss: 0.5556 - val_categorical_accuracy: 0.8381
# Epoch 122/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5262 - categorical_accuracy: 0.8463 - val_loss: 0.5707 - val_categorical_accuracy: 0.8333
# Epoch 123/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5065 - categorical_accuracy: 0.8515 - val_loss: 0.5377 - val_categorical_accuracy: 0.8447
# Epoch 124/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5451 - categorical_accuracy: 0.8400 - val_loss: 0.5791 - val_categorical_accuracy: 0.8321
# Epoch 125/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5372 - categorical_accuracy: 0.8423 - val_loss: 0.6056 - val_categorical_accuracy: 0.8214
# Epoch 126/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5146 - categorical_accuracy: 0.8505 - val_loss: 0.5396 - val_categorical_accuracy: 0.8448
# Epoch 127/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5152 - categorical_accuracy: 0.8495 - val_loss: 0.5511 - val_categorical_accuracy: 0.8399
# Epoch 128/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5107 - categorical_accuracy: 0.8490 - val_loss: 0.5497 - val_categorical_accuracy: 0.8393
# Epoch 129/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5013 - categorical_accuracy: 0.8538 - val_loss: 0.5418 - val_categorical_accuracy: 0.8425
# Epoch 130/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5045 - categorical_accuracy: 0.8530 - val_loss: 0.5270 - val_categorical_accuracy: 0.8486
# Epoch 131/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5158 - categorical_accuracy: 0.8498 - val_loss: 0.5745 - val_categorical_accuracy: 0.8309
# Epoch 132/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5028 - categorical_accuracy: 0.8534 - val_loss: 0.5232 - val_categorical_accuracy: 0.8481
# Epoch 133/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5000 - categorical_accuracy: 0.8541 - val_loss: 0.5344 - val_categorical_accuracy: 0.8450
# Epoch 134/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5065 - categorical_accuracy: 0.8522 - val_loss: 0.5689 - val_categorical_accuracy: 0.8292
# Epoch 135/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.5021 - categorical_accuracy: 0.8533 - val_loss: 0.5343 - val_categorical_accuracy: 0.8445
# Epoch 136/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5040 - categorical_accuracy: 0.8521 - val_loss: 0.5405 - val_categorical_accuracy: 0.8403
# Epoch 137/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.4932 - categorical_accuracy: 0.8560 - val_loss: 0.5154 - val_categorical_accuracy: 0.8504
# Epoch 138/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.4982 - categorical_accuracy: 0.8550 - val_loss: 0.5657 - val_categorical_accuracy: 0.8355
# Epoch 139/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.4971 - categorical_accuracy: 0.8556 - val_loss: 0.5224 - val_categorical_accuracy: 0.8471
# Epoch 140/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.4819 - categorical_accuracy: 0.8604 - val_loss: 0.5266 - val_categorical_accuracy: 0.8469
# Epoch 141/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.4916 - categorical_accuracy: 0.8568 - val_loss: 0.5530 - val_categorical_accuracy: 0.8359
# Epoch 142/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.5344 - categorical_accuracy: 0.8448 - val_loss: 0.5618 - val_categorical_accuracy: 0.8397
# Epoch 143/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.4958 - categorical_accuracy: 0.8556 - val_loss: 0.5279 - val_categorical_accuracy: 0.8454
# Epoch 144/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.4821 - categorical_accuracy: 0.8605 - val_loss: 0.5280 - val_categorical_accuracy: 0.8471
# Epoch 145/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.4829 - categorical_accuracy: 0.8601 - val_loss: 0.5261 - val_categorical_accuracy: 0.8471
# Epoch 146/170
# 5/5 [==============================] - 19s 4s/step - loss: 0.4890 - categorical_accuracy: 0.8580 - val_loss: 0.5232 - val_categorical_accuracy: 0.8458
# Epoch 147/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.4822 - categorical_accuracy: 0.8606 - val_loss: 0.5164 - val_categorical_accuracy: 0.8511
# Epoch 148/170
# 5/5 [==============================] - 18s 4s/step - loss: 0.4786 - categorical_accuracy: 0.8615 - val_loss: 0.5259 - val_categorical_accuracy: 0.8469
# Epoch 149/170
# 4/5 [=======================>......] - ETA: 3s - loss: 0.4708 - categorical_accuracy: 0.8643
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-1380ed8ec56a> in <module>()
#      11
#      12 history = model.fit(training_dataset,
# ---> 13                     steps_per_epoch=steps_per_epoch, validation_data=validation_dataset, validation_steps=validation_steps, epochs=EPOCHS)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate the Model
#
# After training, you will want to see how your model is doing on a test set. For segmentation models, you can use the intersection-over-union and the dice score as metrics to evaluate your model. You'll see how it is implemented in this section.

# %%
def get_images_and_segments_test_arrays():
  '''
  Gets a subsample of the val set as your test set

  Returns:
    Test set containing ground truth images and label maps
  '''
  y_true_segments = []
  y_true_images = []
  test_count = 64

  ds = validation_dataset.unbatch()
  ds = ds.batch(101)

  for image, annotation in ds.take(1):
    y_true_images = image
    y_true_segments = annotation

  y_true_segments = y_true_segments[:test_count, : ,: , :]
  y_true_segments = np.argmax(y_true_segments, axis=3)  

  return y_true_images, y_true_segments

# load the ground truth images and segmentation masks
y_true_images, y_true_segments = get_images_and_segments_test_arrays()

# %% [markdown]
# ### Make Predictions
#
# You can get output segmentation masks by using the `predict()` method. As you may recall, the output of our segmentation model has the shape `(height, width, 12)` where `12` is the number of classes. Each pixel value in those 12 slices indicates the probability of that pixel belonging to that particular class. If you want to create the predicted label map, then you can get the `argmax()` of that axis. This is shown in the following cell.

# %%
results = model.predict(validation_dataset, steps=validation_steps)
results = np.argmax(results, axis=-1)

# %%
# get the model prediction
results = model.predict(validation_dataset, steps=validation_steps)

# for each pixel, get the slice number which has the highest probability
results = np.argmax(results, axis=3)

# %% [markdown]
# ### Compute Metrics
#
# The function below generates the IOU and dice score of the prediction and ground truth masks. From the lectures, it is given that:
#
# $$IOU = \frac{area\_of\_overlap}{area\_of\_union}$$
# <br>
# $$Dice Score = 2 * \frac{area\_of\_overlap}{combined\_area}$$
#
# The code below does that for you. A small smoothening factor is introduced in the denominators to prevent possible division by zero.

# %%
def compute_metrics(y_true, y_pred):
  '''
  Computes IOU and Dice Score.

  Args:
    y_true (tensor) - ground truth label map
    y_pred (tensor) - predicted label map
  '''
  
  class_wise_iou = []
  class_wise_dice_score = []

  smoothening_factor = 0.00001

  for i in range(12):
    intersection = np.sum((y_pred == i) * (y_true == i))
    y_true_area = np.sum((y_true == i))
    y_pred_area = np.sum((y_pred == i))
    combined_area = y_true_area + y_pred_area
    
    iou = (intersection + smoothening_factor) / (combined_area - intersection + smoothening_factor)
    class_wise_iou.append(iou)
    
    dice_score =  2 * ((intersection + smoothening_factor) / (combined_area + smoothening_factor))
    class_wise_dice_score.append(dice_score)

  return class_wise_iou, class_wise_dice_score

# %% [markdown]
# ### Show Predictions and Metrics
#
# You can now see the predicted segmentation masks side by side with the ground truth. The metrics are also overlayed so you can evaluate how your model is doing.

# %%
# input a number from 0 to 63 to pick an image from the test set
integer_slider = 25

# compute metrics
iou, dice_score = compute_metrics(y_true_segments[integer_slider], results[integer_slider])  

# visualize the output and metrics
show_predictions(y_true_images[integer_slider], [results[integer_slider], y_true_segments[integer_slider]], ["Image", "Predicted Mask", "True Mask"], iou, dice_score)

# %% [markdown]
# ### Display Class Wise Metrics
#
# You can also compute the class-wise metrics so you can see how your model performs across all images in the test set.

# %%
# compute class-wise metrics
cls_wise_iou, cls_wise_dice_score = compute_metrics(y_true_segments, results)

# %%
# print IOU for each class
for idx, iou in enumerate(cls_wise_iou):
  spaces = ' ' * (13-len(class_names[idx]) + 2)
  print("{}{}{} ".format(class_names[idx], spaces, iou))
# Out:
# sky            0.8849596611836307
# building       0.8054518394474022
# column/pole    4.68296337703336e-10
# road           0.8957871652464363
# side walk      0.6688610588414935
# vegetation     0.8337352308967143
# traffic light  0.00020990794044323257
# fence          0.2269818250068535
# vehicle        0.38464948622911316
# pedestrian     0.02629469945185868
# byciclist      0.03482657944094771
# void           0.11792110300439942

# %%
# print the dice score for each class
for idx, dice_score in enumerate(cls_wise_dice_score):
  spaces = ' ' * (13-len(class_names[idx]) + 2)
  print("{}{}{} ".format(class_names[idx], spaces, dice_score))
# Out:
# sky            0.9389693365036604
# building       0.8922440597460274
# column/pole    9.36592675406672e-10
# road           0.945029253993227
# side walk      0.8015778848793524
# vegetation     0.9093300023435109
# traffic light  0.00041972777681914916
# fence          0.36998400529346476
# vehicle        0.5555911298488078
# pedestrian     0.05124200578192696
# byciclist      0.06730901609534631
# void           0.21096498259004587

# %% [markdown]
# **That's all for this lab! In the next section, you will work on another architecture for building a segmentation model: the UNET.**
